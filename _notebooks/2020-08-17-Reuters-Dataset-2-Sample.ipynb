# %% [markdown]
# # "Reuters Dataset 2 Sample"
# > "Reuters Dataset 2 Sample"
# - toc: false
# - branch: master
# - badges: false
# - comments: true
# - categories: [long, short, longshort]
# - hide: false
# - search_exclude: true
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2

# %% [markdown]
# Below is dataframe sample of our Reuters Dataset 2

# %%
#hide_input
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import seaborn as sns
import os
import time
import gc
import glob
import matplotlib.pyplot as plt

# %%
#hide_input
df_tes=pd.read_pickle('D:\\Downloads\\Reuters-full-data-set_processed_titled_download.pkl')

# %%
#hide_input
df_tes.head(50)
# Out:
#                                                  href                      ts  \
# 0   http://www.reuters.com/article/ousiv/idUSN2922...  20070101Â 07:12 PM EST
# 1   http://www.reuters.com/article/ousiv/idUSN2922...  20070101Â 08:39 AM EST
# 2   http://www.reuters.com/article/ousiv/idUSN0231...  20070102Â 08:18 PM EST
# 3   http://www.reuters.com/article/ousiv/idUSN0234...  20070102Â 06:00 PM EST
# 4   http://www.reuters.com/article/ousiv/idUSN0234...  20070102Â 02:49 PM EST
# 5   http://www.reuters.com/article/businessNews/id...  20070102Â 02:49 PM EST
# 6   http://www.reuters.com/article/companyNewsAndP...  20070102Â 02:47 PM EST
# 7   http://www.reuters.com/article/companyNewsAndP...  20070102Â 11:51 AM EST
# 8   http://www.reuters.com/article/businessNews/id...  20070102Â 11:39 AM EST
# 9   http://www.reuters.com/article/companyNewsAndP...  20070102Â 11:21 AM EST
# 10  http://www.reuters.com/article/ousiv/idUSN0232...  20070102Â 11:15 AM EST
# ...
