# %% [markdown]
# # "2019 January One Day Holding Long Short Portfolio BackTest"
# > "2019 January Portfolio"
# - toc: false
# - branch: master
# - badges: false
# - comments: true
# - categories: [long, short, longshort]
# - hide: false
# - search_exclude: true
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2

# %%
#hide_input
import numpy as np
import pandas as pd
import seaborn as sns
import os
import time
import gc
import glob
import matplotlib.pyplot as plt

# %%
#hide_input
df_testp=pd.read_csv('D:\\Downloads\\20194dayreturnpred2019train60K.csv')

# %%
#hide
df_testp=df_testp.loc[df_testp.Date>=20190101].loc[df_testp.Date<20190201].sort_values(by='Date',ascending=True).copy()

# %% [markdown]
# **Long-Short Portfolio**

# %%
#hide
df_agg=df_testp[['Date','pred','labelr1']].groupby(['Date','pred']).sum().reset_index();
df_agg['cumreturn1']=0.0
for l in range(len(df_agg)):
    df_agg['cumreturn1'][l]=np.prod((1+(df_agg['labelr1']/100))[:l])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#hide_input
df_agg
# Out:
#         Date  pred    labelr1  cumreturn1
# 0   20190104   1.0  -3.755620    1.000000
# 1   20190107   1.0  16.666667    0.962444
# 2   20190110   1.0  -5.454545    1.122851
# 3   20190111   1.0  -3.895267    1.061605
# 4   20190114   1.0   1.753056    1.020252
# 5   20190115   1.0  -9.090909    1.038138
# 6   20190117   1.0   0.746269    0.943762
# 7   20190118   1.0   0.000000    0.950805
# 8   20190123   1.0  25.178736    0.950805
# 9   20190124   1.0  -6.909605    1.190205
# 10  20190125   1.0  -0.476167    1.107967
# 11  20190128   1.0   3.243158    1.102691
# 12  20190129   1.0  -1.774443    1.138453
# 13  20190130   1.0  -3.237440    1.118252
# 14  20190131   1.0  -1.788903    1.082049

# %%
#hide_input
import altair as alt
import datetime
df_agg['Date']=df_agg['Date'].astype(str).str[:4]+'-'+df_agg['Date'].astype(str).str[4:6]+'-'+df_agg['Date'].astype(str).str[6:]
df_agg['Date']=df_agg['Date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d"))
#df_agg['Date']='-'.join([df_agg['Date'][:4], df_agg['Date'][4:6], df_agg['Date'][6:]])
alt.Chart(df_agg).mark_trail().encode(
    x='Date:T',
    y='cumreturn1:Q',
    size='cumreturn1'
).properties(
    width=1000,
    height=1000
)
# Out:
# alt.Chart(...)

# %% [markdown]
# **Long portfolio**

# %%
#hide
df_agg=df_testp[['Date','pred','labelr1']].loc[df_testp.pred==1.0].groupby(['Date','pred']).sum().reset_index();
df_agg['cumreturn1']=0.0
for l in range(len(df_agg)):
    df_agg['cumreturn1'][l]=np.prod((1+(df_agg['labelr1']/100))[:l])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#hide_input
df_agg
# Out:
#         Date  pred    labelr1  cumreturn1
# 0   20190104   1.0  -3.755620    1.000000
# 1   20190107   1.0  16.666667    0.962444
# 2   20190110   1.0  -5.454545    1.122851
# 3   20190111   1.0  -3.895267    1.061605
# 4   20190114   1.0   1.753056    1.020252
# 5   20190115   1.0  -9.090909    1.038138
# 6   20190117   1.0   0.746269    0.943762
# 7   20190118   1.0   0.000000    0.950805
# 8   20190123   1.0  25.178736    0.950805
# 9   20190124   1.0  -6.909605    1.190205
# 10  20190125   1.0  -0.476167    1.107967
# 11  20190128   1.0   3.243158    1.102691
# 12  20190129   1.0  -1.774443    1.138453
# 13  20190130   1.0  -3.237440    1.118252
# 14  20190131   1.0  -1.788903    1.082049

# %%
#hide_input
import altair as alt
df_agg['Date']=df_agg['Date'].astype(str).str[:4]+'-'+df_agg['Date'].astype(str).str[4:6]+'-'+df_agg['Date'].astype(str).str[6:]
df_agg['Date']=df_agg['Date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d"))
#df_agg['Date']='-'.join([df_agg['Date'][:4], df_agg['Date'][4:6], df_agg['Date'][6:]])
alt.Chart(df_agg).mark_trail().encode(
    x='Date:T',
    y='cumreturn1:Q',
    size='cumreturn1'
).properties(
    width=1000,
    height=1000
)
# Out:
# alt.Chart(...)

# %% [markdown]
# **Short Portfolio**

# %%
#hide
df_agg=df_testp[['Date','pred','labelr1']].loc[df_testp.pred==-1.0].groupby(['Date','pred']).sum().reset_index();
df_agg['cumreturn1']=0.0
for l in range(len(df_agg)):
    df_agg['cumreturn1'][l]=np.prod((1+(df_agg['labelr1']/100))[:l])

# %%
#hide_input
df_agg
# Out:
# Empty DataFrame
# Columns: [Date, pred, labelr1, cumreturn1]
# Index: []

# %%
#hide_input
import altair as alt
df_agg['Date']=df_agg['Date'].astype(str).str[:4]+'-'+df_agg['Date'].astype(str).str[4:6]+'-'+df_agg['Date'].astype(str).str[6:]
df_agg['Date']=df_agg['Date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d"))
#df_agg['Date']='-'.join([df_agg['Date'][:4], df_agg['Date'][4:6], df_agg['Date'][6:]])
alt.Chart(df_agg).mark_trail().encode(
    x='Date:T',
    y='cumreturn1:Q',
    size='cumreturn1'
).properties(
    width=1000,
    height=1000
)
# Out:
# alt.Chart(...)
