# %% [markdown]
# # "Reuters Dataset 1 Sample"
# > "Reuters Dataset 1 Sample"
# - toc: false
# - branch: master
# - badges: false
# - comments: true
# - categories: [long, short, longshort]
# - hide: false
# - search_exclude: true
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2

# %% [markdown]
# Below is dataframe sample of our Reuters Dataset 1

# %%
#hide_input
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import seaborn as sns
import os
import time
import gc
import glob
import matplotlib.pyplot as plt

# %%
#hide_input
df_tes=pd.read_csv('D:\\Downloads\\reuters_processed_datapred.csv')

# %%
#hide_input
df_tes[['raw_header', 'reuters_url', 'stock',
       'article_publish_date', 'full_article', 'processed_header',]].head(50)
# Out:
#                                            raw_header  \
# 0   Canadian telecom company BCE says customer dat...
# 1   BRIEF-Carl Icahn says pleased with AIG board o...
# 2   AIG lures industry veteran Duperreault as CEO ...
# 3   AIG lures industry veteran Duperreault as CEO ...
# 4   SEC says ex-Nomura trading chief lied about bo...
# 5   UPDATE 1-MSCI upgrades Pakistan and adds 57 se...
# 6   Philadelphia sues Wells Fargo, alleges predato...
# 7   Philadelphia sues Wells Fargo, alleges predato...
# 8   BRIEF-Soros Fund Management more than triples ...
# 9   BRIEF-Soros Fund Management takes share stake ...
# 10  MetLife's Brighthouse unit unveils new annuity...
# 11  BRIEF-Tiger Global Management cuts share stake...
# 12  BRIEF-Berkshire Hathaway raises share stake in...
# 13  BRIEF-AIG, Hamilton Insurance and Two Sigma In...
# 14  AIG names turnaround expert Duperreault as CEO...
# 15  BRIEF-DSM announces Thermo Fisher will commenc...
# ...
